# %%
import pickle as pk
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # TASK B2

# %% [markdown]
# # CNN DENSE

# %%
pkl_file = open('./CNN_DENSE/results_PCA_CNN_DENSE_new_5.pkl', 'rb')
pca_5 = pk.load(pkl_file)
pkl_file = open('./CNN_DENSE/results_PCA_CNN_DENSE_new_10.pkl', 'rb')
pca_10 = pk.load(pkl_file)
pkl_file = open('./CNN_DENSE/results_PCA_CNN_DENSE_new_20.pkl', 'rb')
pca_20 = pk.load(pkl_file)
pkl_file = open('./CNN_DENSE/results_PCA_CNN_DENSE_new_40.pkl', 'rb')
pca_40 = pk.load(pkl_file)
pkl_file = open('./CNN_DENSE/results_PCA_CNN_DENSE_new_80.pkl', 'rb')
pca_80 = pk.load(pkl_file)

pkl_file = open('./CNN_DENSE/results_all_subjects_CNN_DENSE_new.pkl', 'rb')
all_channels = pk.load(pkl_file)

print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(5, np.amax(pca_5[0]), np.amax(pca_5[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(10, np.amax(pca_10[0]), np.amax(pca_10[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(20, np.amax(pca_20[0]), np.amax(pca_20[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(40, np.amax(pca_40[0]), np.amax(pca_40[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(80, np.amax(pca_80[0]), np.amax(pca_80[1])))

print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(113, np.amax(all_channels[0]), np.amax(all_channels[1])))

dense_scores = [np.amax(pca_5[1]), np.amax(pca_10[1]), np.amax(pca_20[1]), np.amax(pca_40[1]), np.amax(pca_80[1]), np.amax(all_channels[1])]
# Out:
# 5 Sensory channels: Test Accuracy is: 0.8194654055882147, F1-score is: 0.7385060406297977
# 10 Sensory channels: Test Accuracy is: 0.8203095000545484, F1-score is: 0.7502553170066854
# 20 Sensory channels: Test Accuracy is: 0.8541245673650792, F1-score is: 0.8317894732984732
# 40 Sensory channels: Test Accuracy is: 0.9000639443751841, F1-score is: 0.8910825069214938
# 80 Sensory channels: Test Accuracy is: 0.9123928872867227, F1-score is: 0.9058055224506283
# 113 Sensory channels: Test Accuracy is: 0.9158204379388478, F1-score is: 0.9097876548451297

# %% [markdown]
# # CNN LSTM

# %%
pkl_file = open('./CNN_LSTM/results_PCA_CNN_LSTM_new_5.pkl', 'rb')
pca_5 = pk.load(pkl_file)
pkl_file = open('./CNN_LSTM/results_PCA_CNN_LSTM_new_10.pkl', 'rb')
pca_10 = pk.load(pkl_file)
pkl_file = open('./CNN_LSTM/results_PCA_CNN_LSTM_new_20.pkl', 'rb')
pca_20 = pk.load(pkl_file)
pkl_file = open('./CNN_LSTM/results_PCA_CNN_LSTM_new_40.pkl', 'rb')
pca_40 = pk.load(pkl_file)
pkl_file = open('./CNN_LSTM/results_PCA_CNN_LSTM_new_80.pkl', 'rb')
pca_80 = pk.load(pkl_file)

pkl_file = open('./CNN_LSTM/results_best_CNN_LSTM_new.pkl', 'rb')
all_channels = pk.load(pkl_file)

print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(5, np.amax(pca_5[0]), np.amax(pca_5[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(10, np.amax(pca_10[0]), np.amax(pca_10[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(20, np.amax(pca_20[0]), np.amax(pca_20[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(40, np.amax(pca_40[0]), np.amax(pca_40[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(80, np.amax(pca_80[0]), np.amax(pca_80[1])))

print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(113, np.amax(all_channels[0]), np.amax(all_channels[1])))

lstm_scores = [np.amax(pca_5[1]), np.amax(pca_10[1]), np.amax(pca_20[1]), np.amax(pca_40[1]), np.amax(pca_80[1]), np.amax(all_channels[1])]
# Out:
# 5 Sensory channels: Test Accuracy is: 0.813531143065532, F1-score is: 0.7414084857106356
# 10 Sensory channels: Test Accuracy is: 0.8079805617168411, F1-score is: 0.7615335922298025
# 20 Sensory channels: Test Accuracy is: 0.834556848584485, F1-score is: 0.8208362563752613
# 40 Sensory channels: Test Accuracy is: 0.8937460067769514, F1-score is: 0.8881770530165533
# 80 Sensory channels: Test Accuracy is: 0.9100396457513071, F1-score is: 0.9066719991328842
# 113 Sensory channels: Test Accuracy is: 0.9136462475671413, F1-score is: 0.9099497030801234

# %% [markdown]
# # MLP

# %%
pkl_file = open('./MLP/results_PCA_MLP_new_5.pkl', 'rb')
pca_5 = pk.load(pkl_file)
pkl_file = open('./MLP/results_PCA_MLP_new_10.pkl', 'rb')
pca_10 = pk.load(pkl_file)
pkl_file = open('./MLP/results_PCA_MLP_new_20.pkl', 'rb')
pca_20 = pk.load(pkl_file)
pkl_file = open('./MLP/results_PCA_MLP_new_40.pkl', 'rb')
pca_40 = pk.load(pkl_file)
pkl_file = open('./MLP/results_PCA_MLP_new_80.pkl', 'rb')
pca_80 = pk.load(pkl_file)

pkl_file = open('./MLP/results_all_subjects_MLP_new.pkl', 'rb')
all_channels = pk.load(pkl_file)

print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(5, np.amax(pca_5[0]), np.amax(pca_5[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(10, np.amax(pca_10[0]), np.amax(pca_10[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(20, np.amax(pca_20[0]), np.amax(pca_20[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(40, np.amax(pca_40[0]), np.amax(pca_40[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(80, np.amax(pca_80[0]), np.amax(pca_80[1])))

print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(113, np.amax(all_channels[0]), np.amax(all_channels[1])))

mlp_scores = [np.amax(pca_5[1]), np.amax(pca_10[1]), np.amax(pca_20[1]), np.amax(pca_40[1]), np.amax(pca_80[1]), np.amax(all_channels[1])]
# Out:
# 5 Sensory channels: Test Accuracy is: 0.819490983977405, F1-score is: 0.7381904918793897
# 10 Sensory channels: Test Accuracy is: 0.8195421407557857, F1-score is: 0.7391543333334291
# 20 Sensory channels: Test Accuracy is: 0.835579999649764, F1-score is: 0.8025325009927295
# 40 Sensory channels: Test Accuracy is: 0.8835912521026646, F1-score is: 0.871960999048401
# 80 Sensory channels: Test Accuracy is: 0.9038751769636061, F1-score is: 0.9010969326437784
# 113 Sensory channels: Test Accuracy is: 0.8978641754618263, F1-score is: 0.8930169650116252

# %% [markdown]
# # MCF

# %%
pkl_file = open('./MCF/results_PCA_MCF_new_5.pkl', 'rb')
pca_5 = pk.load(pkl_file)
pkl_file = open('./MCF/results_PCA_MCF_new_10.pkl', 'rb')
pca_10 = pk.load(pkl_file)
pkl_file = open('./MCF/results_PCA_MCF_new_20.pkl', 'rb')
pca_20 = pk.load(pkl_file)
pkl_file = open('./MCF/results_PCA_MCF_new_40.pkl', 'rb')
pca_40 = pk.load(pkl_file)
pkl_file = open('./MCF/results_PCA_MCF_new_80.pkl', 'rb')
pca_80 = pk.load(pkl_file)


print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(5, np.amax(pca_5[0]), np.amax(pca_5[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(10, np.amax(pca_10[0]), np.amax(pca_10[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(20, np.amax(pca_20[0]), np.amax(pca_20[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(40, np.amax(pca_40[0]), np.amax(pca_40[1])))
print('{0} Sensory channels: Test Accuracy is: {1}, F1-score is: {2}'.format(80, np.amax(pca_80[0]), np.amax(pca_80[1])))

mcf_scores = [np.amax(pca_5[1]), np.amax(pca_10[1]), np.amax(pca_20[1]), np.amax(pca_40[1]), np.amax(pca_80[1]), 0.8807866]
# Out:
# 5 Sensory channels: Test Accuracy is: 0.8191630857376714, F1-score is: 0.7377328248315476
# 10 Sensory channels: Test Accuracy is: 0.8191630857376714, F1-score is: 0.7377328248315476
# 20 Sensory channels: Test Accuracy is: 0.8212093308778392, F1-score is: 0.7431637738038032
# 40 Sensory channels: Test Accuracy is: 0.8594741149989769, F1-score is: 0.828635337557057
# 80 Sensory channels: Test Accuracy is: 0.8863310824636792, F1-score is: 0.8727226411678194

# %%
# graphs all models
n_components = [5, 10, 20, 40, 80, 113]

plt.figure(figsize=(10, 7), dpi=300)
plt.grid(b=True, which='major', color='k', linestyle='--', alpha = 0.4)
plt.plot(n_components, dense_scores, '-D')
plt.plot(n_components, lstm_scores, '-D')
plt.plot(n_components, mlp_scores, '-D')
plt.plot(n_components, mcf_scores, '-D')
plt.minorticks_on()
plt.title('CNN + DENSE model task B2: f1_score using different number of channels')
plt.ylabel('f1-score')
plt.xlabel('Number of sensor channels')
plt.show()

#plt.savefig('CNN_DENSE_results_taskB2.eps', format='eps')

# %% [markdown]
# # REDUCED

# %%
pkl_file = open('./CNN_DENSE/reduced/results_CNN_DENSE_acc.pkl', 'rb')
conf1 = pk.load(pkl_file)
pkl_file = open('./CNN_DENSE/reduced/18_channels_imu/results_CNN_DENSE_imu.pkl', 'rb')
conf2 = pk.load(pkl_file)

print('ACC: Test Accuracy is: {}, F1-score is: {}'.format(np.amax(conf1[0]), np.amax(conf1[1])))
print('IMU: Test Accuracy is: {}, F1-score is: {}'.format(np.amax(conf2[0]), np.amax(conf2[1])))
print('DENSE')
# Out:
# ACC: Test Accuracy is: 0.8384959710835038, F1-score is: 0.8007346023436103
# IMU: Test Accuracy is: 0.8986826983997166, F1-score is: 0.8897642574643864
# DENSE

# %%
pkl_file = open('./CNN_LSTM/reduced/results_CNN_LSTM_acc.pkl', 'rb')
conf1 = pk.load(pkl_file)
pkl_file = open('./CNN_LSTM/reduced/results_CNN_LSTM_imu.pkl', 'rb')
conf2 = pk.load(pkl_file)

print('ACC: Test Accuracy is: {}, F1-score is: {}'.format(np.amax(conf1[0]), np.amax(conf1[1])))
print('IMU: Test Accuracy is: {}, F1-score is: {}'.format(np.amax(conf2[0]), np.amax(conf2[1])))
print('LSTM')
# Out:
# ACC: Test Accuracy is: 0.8103849577437217, F1-score is: 0.7996482997167861
# IMU: Test Accuracy is: 0.9134416172519366, F1-score is: 0.910716317545752
# LSTM

# %%
pkl_file = open('./CNN_DENSE/single-subject/results_CNN_DENSE_user_1.pkl', 'rb')
user_1 = pk.load(pkl_file)
pkl_file = open('./CNN_DENSE/single-subject/results_CNN_DENSE_user_2.pkl', 'rb')
user_2 = pk.load(pkl_file)
pkl_file = open('./CNN_DENSE/single-subject/results_CNN_DENSE_user_3.pkl', 'rb')
user_3 = pk.load(pkl_file)
pkl_file = open('./CNN_DENSE/single-subject/results_CNN_DENSE_user_4.pkl', 'rb')
user_4 = pk.load(pkl_file)


print('User {0}: Test Accuracy is: {1}, F1-score is: {2}'.format(1, np.amax(user_1[0]), np.amax(user_1[1])))
print('User {0}: Test Accuracy is: {1}, F1-score is: {2}'.format(2, np.amax(user_2[0]), np.amax(user_2[1])))
print('User {0}: Test Accuracy is: {1}, F1-score is: {2}'.format(3, np.amax(user_3[0]), np.amax(user_3[1])))
print('User {0}: Test Accuracy is: {1}, F1-score is: {2}'.format(4, np.amax(user_4[0]), np.amax(user_4[1])))
# Out:
# User 1: Test Accuracy is: 0.9091341566971435, F1-score is: 0.9009958263457923
# User 2: Test Accuracy is: 0.9310344842654953, F1-score is: 0.9276644853081976
# User 3: Test Accuracy is: 0.9192333323131927, F1-score is: 0.9153726136126534
# User 4: Test Accuracy is: 0.8954374697621005, F1-score is: 0.8848250138628407
